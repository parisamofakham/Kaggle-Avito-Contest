# %% [markdown]
# # Avito Demand Challenge Kaggle Competition
# #### Submission by Huilin Cai, Minxuan Chen, Jordan Fischer and Parisa Mofakham

# %% [markdown]
# *The final submission can be found under team name HMJP at:
# <br> https://www.kaggle.com/c/avito-demand-prediction/submissions?sortBy=date&group=all&page=1*

# %% [markdown]
# ________________________________________________________________________________________________

# %% [markdown]
# ### Model building
#
# 1. Data preprocessing
# <br> a. Text, geographic, price, time features
# <br> b. Image features
# <br>
# <br>
# 2. Base models
# <br> a. Neural Network
# <br> b. XGBoost
# <br> c. Ridge (L1 regularization)
# <br> d. LightGBM
# <br> e. LightGBM with categorical variables as categorical
# <br> f. Recurrent Neural Network  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;     ***note that this model does not include the same data preprocessing as the other base models***
# <br>
# <br>
# 3. Stacked model
# <br> a. Stacked model combining base models (a), (b), and (c) from (2)
# <br>
# <br>
# 4. Blended model
# <br> a. Blended model using the stacked model from (3), and base models (b), (c), (d), (e), and (f) from (2)

# %%
from IPython.display import Image
from IPython.display import display
# %matplotlib inline

display(Image(('ModelDiagram.png')))
